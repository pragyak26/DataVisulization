# %%
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv("/content/gdrive/MyDrive/business_dynamics.csv")

# %%
df.head(2)
# Out:
#      State  Year  Data.DHS Denominator  Data.Number of Firms  \
# 0  Alabama  1978                972627                 54597
# 1  Alabama  1979               1037995                 55893
#
#    Data.Calculated.Net Job Creation  Data.Calculated.Net Job Creation Rate  \
# 0                             74178                                  7.627
# 1                             58099                                  5.597
#
#    Data.Calculated.Reallocation Rate  Data.Establishments.Entered  \
# 0                             29.183                        10457
# 1                             31.251                         9668
#
#    Data.Establishments.Entered Rate  Data.Establishments.Exited  ...  \
# 0                            16.375                        7749  ...
# 1                            14.701                        7604  ...
#
#    Data.Job Creation.Births  Data.Job Creation.Continuers  \
# 0                     76167                        139930
# 1                     76618                        143675
#
#    Data.Job Creation.Count  Data.Job Creation.Rate  \
# 0                   216097                  22.218
# 1                   220293                  21.223
#
#    Data.Job Creation.Rate/Births  Data.Job Destruction.Continuers  \
# 0                          7.831                            81829
# 1                          7.381                           101842
#
#    Data.Job Destruction.Count  Data.Job Destruction.Deaths  \
# 0                      141919                        60090
# 1                      162194                        60352
#
#    Data.Job Destruction.Rate  Data.Job Destruction.Rate/Deaths
# 0                     14.591                             6.178
# 1                     15.626                             5.814
#
# [2 rows x 25 columns]

# %%
print(df[['Data.Number of Firms']].mean())
print(df.loc[df['State'] == 'Alabama', 'Data.Job Destruction.Rate'].mean())
# Out:
# Data.Number of Firms    96965.200311
# dtype: float64
# 14.091756097560976

# %%
unique_states = df['State'].unique()

# %%
unique_states
# Out:
# array(['Alabama', 'Alaska', 'Arkansas', 'California', 'Colorado',
#        'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii',
#        'Idaho', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
sb = list()

# %%
for state in unique_states:
  # print(state, df.loc[df['State'] == state, 'Data.Job Destruction.Rate'].mean())
  m=(df.loc[df['State'] == state, 'Data.Job Destruction.Rate'].mean())
  sb.append(m)

print(sb)
# Out:
# [14.091756097560976, 17.04039024390244, 15.822097560975607, 13.489536585365855, 15.634341463414632, 15.466341463414631, 13.197487804878048, 13.947219512195122, 13.423219512195121, 16.037195121951218, 14.663853658536585, 13.426146341463415, 14.814414634146344, 13.590390243902439, 12.994536585365855, 12.197536585365855, 13.365902439024392, 13.447999999999999, 15.189536585365852, 12.900365853658538, 13.97819512195122, 13.09339024390244, 13.728682926829268, 12.702414634146344, 13.712121951219512, 13.356731707317072, 14.517585365853655, 12.512951219512194, 15.22931707317073, 13.083341463414635, 14.401024390243906, 15.573560975609759, 13.680146341463415, 13.140951219512194, 12.681268292682928, 13.185317073170731, 14.969195121951222, 14.328682926829268, 12.808536585365855, 13.192414634146342, 13.595341463414634, 12.34070731707317, 13.841756097560975, 15.766682926829265, 14.870707317073173, 12.543024390243902, 13.692756097560974]

# %%
print(len(sb))
# Out:
# 47

# %%
test_list=[sb,unique_states]

# %%
newData = pd.DataFrame(test_list, index=['mean', 'state']).T
newData
# Out:
#          mean                 state
# 0   14.091756               Alabama
# 1    17.04039                Alaska
# 2   15.822098              Arkansas
# 3   13.489537            California
# 4   15.634341              Colorado
# 5   15.466341              Delaware
# 6   13.197488  District of Columbia
# 7    13.94722               Florida
# 8    13.42322               Georgia
# 9   16.037195                Hawaii
# 10  14.663854                 Idaho
# 11  13.426146               Indiana
# 12  14.814415                  Iowa
# 13   13.59039                Kansas
# 14  12.994537              Kentucky
# 15  12.197537             Louisiana
# 16  13.365902                 Maine
# 17     13.448              Maryland
# 18  15.189537         Massachusetts
# 19  12.900366              Michigan
# 20  13.978195             Minnesota
# 21   13.09339           Mississippi
# 22  13.728683              Missouri
# 23  12.702415               Montana
# 24  13.712122              Nebraska
# 25  13.356732                Nevada
# 26  14.517585         New Hampshire
# 27  12.512951            New Jersey
# 28  15.229317            New Mexico
# 29  13.083341              New York
# 30  14.401024        North Carolina
# 31  15.573561          North Dakota
# 32  13.680146                  Ohio
# 33  13.140951              Oklahoma
# 34  12.681268                Oregon
# 35  13.185317          Pennsylvania
# 36  14.969195          Rhode Island
# 37  14.328683        South Carolina
# 38  12.808537          South Dakota
# 39  13.192415                 Texas
# 40  13.595341                  Utah
# 41  12.340707               Vermont
# 42  13.841756              Virginia
# 43  15.766683            Washington
# 44  14.870707         West Virginia
# 45  12.543024             Wisconsin
# 46  13.692756               Wyoming

# %%
def viz_meanOfState(data):
  #data = data.loc[data['Year'].isin(years)]
  # data["life_expectancy_at_birth_all"] = (data["life_expectancy_at_birth_men"]*data["total_population_male"] + data["life_expectancy_at_birth_women"]*data["total_population_female"])/(data["total_population_male"] + data["total_population_female"])

  fig = px.sunburst(data, path=['state','mean'], values='mean',
                    color='mean', hover_data=['mean'],
                    color_continuous_scale='RdBu',)
                                        
  fig.show()

# %%
viz_meanOfState(newData)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0e8a2b5e-22d8-49e4-811e-b6cb315b1dae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e8a2b5e-22d8-49e4-811e-b6cb315b1dae")) {                    Plotly.newPlot(                        "0e8a2b5e-22d8-49e4-811e-b6cb315b1dae",                        [{"branchvalues":"total","customdata":[[12.197536585365855,12.197536585365855],[12.34070731707317,12.34070731707317],[12.512951219512196,12.512951219512196],[12.543024390243902,12.543024390243902],[12.681268292682928,12.681268292682928],[12.702414634146344,12.702414634146344],[12.808536585365855,12.808536585365855],[12.900365853658538,12.900365853658538],[