# %%
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv("/content/gdrive/MyDrive/business_dynamics.csv")

# %%
df.head(2)
# Out:
#      State  Year  Data.DHS Denominator  Data.Number of Firms  \
# 0  Alabama  1978                972627                 54597
# 1  Alabama  1979               1037995                 55893
#
#    Data.Calculated.Net Job Creation  Data.Calculated.Net Job Creation Rate  \
# 0                             74178                                  7.627
# 1                             58099                                  5.597
#
#    Data.Calculated.Reallocation Rate  Data.Establishments.Entered  \
# 0                             29.183                        10457
# 1                             31.251                         9668
#
#    Data.Establishments.Entered Rate  Data.Establishments.Exited  ...  \
# 0                            16.375                        7749  ...
# 1                            14.701                        7604  ...
#
#    Data.Job Creation.Births  Data.Job Creation.Continuers  \
# 0                     76167                        139930
# ...

# %%
print(df[['Data.Number of Firms']].mean())
print(df.loc[df['State'] == 'Alabama', 'Data.Job Destruction.Rate'].mean())
# Out:
# Data.Number of Firms    96965.200311
# dtype: float64
# 14.091756097560976

# %%
unique_states = df['State'].unique()

# %%
unique_states
# Out:
# array(['Alabama', 'Alaska', 'Arkansas', 'California', 'Colorado',
#        'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii',
#        'Idaho', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
sb = list()

# %%
for state in unique_states:
  # print(state, df.loc[df['State'] == state, 'Data.Job Destruction.Rate'].mean())
  m=(df.loc[df['State'] == state, 'Data.Job Creation.Rate'].mean())
  sb.append(m)

print(sb)
# Out:
# [15.720146341463415, 19.478048780487807, 19.52965853658537, 15.329512195121952, 17.822536585365853, 18.321024390243903, 14.08468292682927, 15.882243902439022, 15.171414634146341, 19.18321951219512, 17.157853658536585, 15.393560975609757, 17.35041463414634, 14.59892682926829, 14.334512195121953, 13.589682926829266, 15.036585365853655, 15.113804878048779, 16.628414634146345, 14.327512195121951, 15.934121951219515, 14.579731707317073, 14.7920243902439, 14.837731707317072, 15.130097560975608, 14.902756097560975, 16.524658536585363, 14.269658536585366, 19.29419512195122, 15.328756097560975, 15.742195121951218, 17.637121951219513, 14.931829268292685, 15.179853658536587, 14.937853658536582, 14.125121951219516, 16.66507317073171, 16.589219512195122, 13.915439024390244, 14.07231707317073, 15.51631707317073, 14.621731707317073, 15.74039024390244, 18.41887804878049, 18.290146341463412, 14.07748780487805, 15.942317073170729]

# %%
print(len(sb))
# Out:
# 47

# %%
test_list=[unique_states, sb]

# %%
newData = pd.DataFrame(test_list, index=['state', 'mean']).T
newData
# Out:
#                    state       mean
# 0                Alabama  15.720146
# 1                 Alaska  19.478049
# 2               Arkansas  19.529659
# 3             California  15.329512
# 4               Colorado  17.822537
# 5               Delaware  18.321024
# 6   District of Columbia  14.084683
# 7                Florida  15.882244
# 8                Georgia  15.171415
# 9                 Hawaii   19.18322
# 10                 Idaho  17.157854
# 11               Indiana  15.393561
# 12                  Iowa  17.350415
# 13                Kansas  14.598927
# 14              Kentucky  14.334512
# 15             Louisiana  13.589683
# 16                 Maine  15.036585
# 17              Maryland  15.113805
# 18         Massachusetts  16.628415
# 19              Michigan  14.327512
# 20             Minnesota  15.934122
# 21           Mississippi  14.579732
# 22              Missouri  14.792024
# 23               Montana  14.837732
# 24              Nebraska  15.130098
# ...

# %%
def viz_meanOfState(data):
  
  fig = px.sunburst(data, path=['state','mean'], values='mean',
                    color='mean', hover_data=['mean'],
                    color_continuous_scale='RdBu',)
                                        
  fig.show()

# %%
viz_meanOfState(newData)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
