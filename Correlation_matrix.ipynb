# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv("/content/gdrive/MyDrive/business_dynamics.csv")

# %%
df.columns
# Out:
# Index(['State', 'Year', 'Data.DHS Denominator', 'Data.Number of Firms',
#        'Data.Calculated.Net Job Creation',
#        'Data.Calculated.Net Job Creation Rate',
#        'Data.Calculated.Reallocation Rate', 'Data.Establishments.Entered',
#        'Data.Establishments.Entered Rate', 'Data.Establishments.Exited',
#        'Data.Establishments.Exited Rate',
#        'Data.Establishments.Physical Locations', 'Data.Firm Exits.Count',
#        'Data.Firm Exits.Establishment Exit', 'Data.Firm Exits.Employments',
#        'Data.Job Creation.Births', 'Data.Job Creation.Continuers',
#        'Data.Job Creation.Count', 'Data.Job Creation.Rate',
#        'Data.Job Creation.Rate/Births', 'Data.Job Destruction.Continuers',
#        'Data.Job Destruction.Count', 'Data.Job Destruction.Deaths',
#        'Data.Job Destruction.Rate', 'Data.Job Destruction.Rate/Deaths'],
#       dtype='object')

# %%
cor = df.corr()

# %%
cor
# Out:
#                                             Year  Data.DHS Denominator  \
# Year                                    1.000000              0.153276
# Data.DHS Denominator                    0.153276              1.000000
# Data.Number of Firms                    0.101283              0.989451
# Data.Calculated.Net Job Creation       -0.102335              0.399919
# Data.Calculated.Net Job Creation Rate  -0.317127             -0.074459
# Data.Calculated.Reallocation Rate      -0.585116              0.030686
# Data.Establishments.Entered             0.017952              0.955484
# Data.Establishments.Entered Rate       -0.679678             -0.043186
# Data.Establishments.Exited              0.080359              0.970364
# Data.Establishments.Exited Rate        -0.447644              0.054487
# Data.Establishments.Physical Locations  0.126537              0.994397
# Data.Firm Exits.Count                   0.058994              0.963382
# ...

# %%
sns.heatmap(data = cor)

# %%
plt.figure(figsize=(18, 14))
sns.heatmap(data = cor, annot = True, cmap = 'vlag')

# %%
df.head(2)
# Out:
#      State  Year  Data.DHS Denominator  Data.Number of Firms  \
# 0  Alabama  1978                972627                 54597
# 1  Alabama  1979               1037995                 55893
#
#    Data.Calculated.Net Job Creation  Data.Calculated.Net Job Creation Rate  \
# 0                             74178                                  7.627
# 1                             58099                                  5.597
#
#    Data.Calculated.Reallocation Rate  Data.Establishments.Entered  \
# 0                             29.183                        10457
# 1                             31.251                         9668
#
#    Data.Establishments.Entered Rate  Data.Establishments.Exited  ...  \
# 0                            16.375                        7749  ...
# 1                            14.701                        7604  ...
#
#    Data.Job Creation.Births  Data.Job Creation.Continuers  \
# 0                     76167                        139930
# ...

# %%
calculated_df = df[['Data.DHS Denominator', 'Data.Number of Firms', 'Data.Calculated.Net Job Creation', 'Data.Calculated.Net Job Creation Rate', 'Data.Calculated.Reallocation Rate']]

# %%
calculated_df
# Out:
#       Data.DHS Denominator  Data.Number of Firms  \
# 0                   972627                 54597
# 1                  1037995                 55893
# 2                  1064141                 54838
# 3                  1051448                 54791
# 4                  1037728                 53219
# ...                    ...                   ...
# 1922               3121032                133693
# 1923               3173176                134663
# 1924               3234346                135969
# 1925               3277473                136785
# 1926               3337281                137189
#
#       Data.Calculated.Net Job Creation  Data.Calculated.Net Job Creation Rate  \
# 0                                74178                                  7.627
# 1                                58099                                  5.597
# 2                                -7253                                 -0.682
# ...

# %%
calculated_cor = calculated_df.corr()
calculated_cor
# Out:
#                                        Data.DHS Denominator  \
# Data.DHS Denominator                               1.000000
# Data.Number of Firms                               0.989451
# Data.Calculated.Net Job Creation                   0.399919
# Data.Calculated.Net Job Creation Rate             -0.074459
# Data.Calculated.Reallocation Rate                  0.030686
#
#                                        Data.Number of Firms  \
# Data.DHS Denominator                               0.989451
# Data.Number of Firms                               1.000000
# Data.Calculated.Net Job Creation                   0.421436
# Data.Calculated.Net Job Creation Rate             -0.050468
# Data.Calculated.Reallocation Rate                  0.072909
#
#                                        Data.Calculated.Net Job Creation  \
# Data.DHS Denominator                                           0.399919
# Data.Number of Firms                                           0.421436
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data = calculated_cor, annot = True, cmap = 'vlag')

# %%
df.head(2)
# Out:
#      State  Year  Data.DHS Denominator  Data.Number of Firms  \
# 0  Alabama  1978                972627                 54597
# 1  Alabama  1979               1037995                 55893
#
#    Data.Calculated.Net Job Creation  Data.Calculated.Net Job Creation Rate  \
# 0                             74178                                  7.627
# 1                             58099                                  5.597
#
#    Data.Calculated.Reallocation Rate  Data.Establishments.Entered  \
# 0                             29.183                        10457
# 1                             31.251                         9668
#
#    Data.Establishments.Entered Rate  Data.Establishments.Exited  ...  \
# 0                            16.375                        7749  ...
# 1                            14.701                        7604  ...
#
#    Data.Job Creation.Births  Data.Job Creation.Continuers  \
# 0                     76167                        139930
# ...

# %%
Establishments_df = df[['Data.DHS Denominator', 'Data.Number of Firms', 'Data.Establishments.Entered', 'Data.Establishments.Entered Rate', 'Data.Establishments.Exited', 'Data.Establishments.Exited Rate', 'Data.Establishments.Physical Locations']]

# %%
Establishments_df
# Out:
#       Data.DHS Denominator  Data.Number of Firms  Data.Establishments.Entered  \
# 0                   972627                 54597                        10457
# 1                  1037995                 55893                         9668
# 2                  1064141                 54838                         8714
# 3                  1051448                 54791                         8371
# 4                  1037728                 53219                         8185
# ...                    ...                   ...                          ...
# 1922               3121032                133693                        16681
# 1923               3173176                134663                        16966
# 1924               3234346                135969                        17461
# 1925               3277473                136785                        16431
# 1926               3337281                137189                        15716
#
# ...

# %%
Establishments_cor = Establishments_df.corr()
Establishments_cor
# Out:
#                                         Data.DHS Denominator  \
# Data.DHS Denominator                                1.000000
# Data.Number of Firms                                0.989451
# Data.Establishments.Entered                         0.955484
# Data.Establishments.Entered Rate                   -0.043186
# Data.Establishments.Exited                          0.970364
# Data.Establishments.Exited Rate                     0.054487
# Data.Establishments.Physical Locations              0.994397
#
#                                         Data.Number of Firms  \
# Data.DHS Denominator                                0.989451
# Data.Number of Firms                                1.000000
# Data.Establishments.Entered                         0.978601
# Data.Establishments.Entered Rate                    0.011659
# Data.Establishments.Exited                          0.986494
# Data.Establishments.Exited Rate                     0.100933
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data = Establishments_cor, annot = True, cmap = 'vlag')

# %%
Firm_Exits_df = df[['Data.DHS Denominator', 'Data.Number of Firms', 'Data.Firm Exits.Count', 'Data.Firm Exits.Establishment Exit', 'Data.Firm Exits.Employments']]
Firm_Exits_df
# Out:
#       Data.DHS Denominator  Data.Number of Firms  Data.Firm Exits.Count  \
# 0                   972627                 54597                   5248
# 1                  1037995                 55893                   5234
# 2                  1064141                 54838                   6058
# 3                  1051448                 54791                   5176
# 4                  1037728                 53219                   6077
# ...                    ...                   ...                    ...
# 1922               3121032                133693                   9255
# 1923               3173176                134663                   9177
# 1924               3234346                135969                   9326
# 1925               3277473                136785                   9787
# 1926               3337281                137189                  10514
#
#       Data.Firm Exits.Establishment Exit  Data.Firm Exits.Employments
# ...

# %%
Firm_Exits_cor = Firm_Exits_df.corr()
Firm_Exits_cor
# Out:
#                                     Data.DHS Denominator  \
# Data.DHS Denominator                            1.000000
# Data.Number of Firms                            0.989451
# Data.Firm Exits.Count                           0.963382
# Data.Firm Exits.Establishment Exit              0.964155
# Data.Firm Exits.Employments                     0.954397
#
#                                     Data.Number of Firms  \
# Data.DHS Denominator                            0.989451
# Data.Number of Firms                            1.000000
# Data.Firm Exits.Count                           0.984574
# Data.Firm Exits.Establishment Exit              0.984660
# Data.Firm Exits.Employments                     0.968031
#
#                                     Data.Firm Exits.Count  \
# Data.DHS Denominator                             0.963382
# Data.Number of Firms                             0.984574
# Data.Firm Exits.Count                            1.000000
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data = Firm_Exits_cor, annot = True, cmap = 'vlag')

# %%
Job_Creation_df = df[['Data.DHS Denominator', 'Data.Number of Firms', 'Data.Job Creation.Births', 'Data.Job Creation.Continuers', 'Data.Job Creation.Count', 'Data.Job Creation.Rate', 'Data.Job Creation.Rate/Births']]
Job_Creation_df
# Out:
#       Data.DHS Denominator  Data.Number of Firms  Data.Job Creation.Births  \
# 0                   972627                 54597                     76167
# 1                  1037995                 55893                     76618
# 2                  1064141                 54838                     65734
# 3                  1051448                 54791                     70115
# 4                  1037728                 53219                     73083
# ...                    ...                   ...                       ...
# 1922               3121032                133693                    125806
# 1923               3173176                134663                    138746
# 1924               3234346                135969                    132492
# 1925               3277473                136785                    115172
# 1926               3337281                137189                    116947
#
#       Data.Job Creation.Continuers  Data.Job Creation.Count  \
# ...

# %%
Job_Creation_cor = Job_Creation_df.corr()
Job_Creation_cor
# Out:
#                                Data.DHS Denominator  Data.Number of Firms  \
# Data.DHS Denominator                       1.000000              0.989451
# Data.Number of Firms                       0.989451              1.000000
# Data.Job Creation.Births                   0.949349              0.961281
# Data.Job Creation.Continuers               0.979624              0.981494
# Data.Job Creation.Count                    0.973076              0.978584
# Data.Job Creation.Rate                    -0.037968              0.010973
# Data.Job Creation.Rate/Births             -0.066157             -0.016166
#
#                                Data.Job Creation.Births  \
# Data.DHS Denominator                           0.949349
# Data.Number of Firms                           0.961281
# Data.Job Creation.Births                       1.000000
# Data.Job Creation.Continuers                   0.980725
# Data.Job Creation.Count                        0.992060
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data = Job_Creation_cor, annot = True, cmap = 'vlag')

# %%
Job_Destruction_df = df[['Data.DHS Denominator', 'Data.Number of Firms', 'Data.Job Destruction.Continuers', 'Data.Job Destruction.Count', 'Data.Job Destruction.Deaths', 'Data.Job Creation.Rate', 'Data.Job Destruction.Rate/Deaths']]
Job_Destruction_df
# Out:
#       Data.DHS Denominator  Data.Number of Firms  \
# 0                   972627                 54597
# 1                  1037995                 55893
# 2                  1064141                 54838
# 3                  1051448                 54791
# 4                  1037728                 53219
# ...                    ...                   ...
# 1922               3121032                133693
# 1923               3173176                134663
# 1924               3234346                135969
# 1925               3277473                136785
# 1926               3337281                137189
#
#       Data.Job Destruction.Continuers  Data.Job Destruction.Count  \
# 0                               81829                      141919
# 1                              101842                      162194
# 2                              120563                      179985
# 3                              121251                      173188
# ...

# %%
Job_Destruction_cor = Job_Destruction_df.corr()
Job_Destruction_cor
# Out:
#                                   Data.DHS Denominator  Data.Number of Firms  \
# Data.DHS Denominator                          1.000000              0.989451
# Data.Number of Firms                          0.989451              1.000000
# Data.Job Destruction.Continuers               0.973836              0.971282
# Data.Job Destruction.Count                    0.973894              0.974416
# Data.Job Destruction.Deaths                   0.961923              0.968349
# Data.Job Creation.Rate                       -0.037968              0.010973
# Data.Job Destruction.Rate/Deaths              0.046638              0.088261
#
#                                   Data.Job Destruction.Continuers  \
# Data.DHS Denominator                                     0.973836
# Data.Number of Firms                                     0.971282
# Data.Job Destruction.Continuers                          1.000000
# Data.Job Destruction.Count                               0.997785
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data = Job_Destruction_cor, annot = True, cmap = 'vlag')
